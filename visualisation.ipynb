# %%
import matplotlib.pyplot as plt
import pandas_datareader as pdr
from technical_indicators import *

# %%
start = "2019-01-01"
end = "2020-12-31"
price_data = pdr.DataReader("^FCHI", "yahoo", start=start, end=end)

# %%
price_data
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2019-01-02  4699.979980  4606.200195  4642.180176  4689.390137  76980400.0
# 2019-01-03  4671.279785  4607.680176  4641.799805  4611.490234  78741500.0
# 2019-01-04  4750.509766  4636.790039  4649.629883  4737.120117  95967400.0
# 2019-01-07  4760.270020  4690.220215  4757.009766  4719.169922  73900700.0
# 2019-01-08  4810.270020  4719.229980  4722.160156  4773.270020  98114900.0
# ...                 ...          ...          ...          ...         ...
# 2020-12-24  5545.709961  5517.009766  5542.490234  5522.009766         0.0
# 2020-12-28  5601.000000  5547.899902  5562.040039  5588.379883  44706900.0
# 2020-12-29  5625.520020  5603.740234  5610.129883  5611.790039         0.0
# 2020-12-30  5625.600098  5594.109863  5603.720215  5599.410156  35280300.0
# 2020-12-31  5598.930176  5551.410156  5573.200195  5551.410156         0.0
#
#               Adj Close
# Date
# 2019-01-02  4689.390137
# ...

# %%
price_data["SMA 20"] = sma(price_data["Adj Close"], 20)
price_data["EMA 40"] = ema(price_data["Adj Close"], 40)
price_data["EMA 10"] = ema(price_data["Adj Close"], 10)

# %%
fig, ax = plt.subplots()

fig.set_size_inches(20, 10)

price_data["Adj Close"].plot(ax=ax)
#price_data["SMA 20"].plot(ax=ax)
price_data["EMA 40"].plot(ax=ax)
price_data["EMA 10"].plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='Date'>
